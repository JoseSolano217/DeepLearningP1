# %%
import numpy as np
import pandas as pd
import statistics as stat
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
df = pd.read_csv("./inmobiliaria.csv")

# %%
print(df.describe())
print("\nValores nulos totales:\n", df.isnull().sum())
print(df.head())
# Out:
#        COD_INMUEBLE         AREA     VLR_CANON  VLR_ADMINISTRACION
# count   6791.000000  6791.000000  6.791000e+03        6.791000e+03
# mean    3396.000000    46.357385  1.112686e+06        1.474904e+05
# std     1960.537171    26.973165  1.427193e+06        1.583145e+05
# min        1.000000    10.000000  0.000000e+00        0.000000e+00
# 25%     1698.500000    23.000000  6.539400e+05        0.000000e+00
# 50%     3396.000000    39.000000  8.123400e+05        1.480000e+05
# 75%     5093.500000    70.000000  1.052160e+06        2.300000e+05
# max     6791.000000   100.000000  2.931983e+07        5.116724e+06
#
# Valores nulos totales:
#  COD_INMUEBLE               0
# NOM_SUCURSAL               0
# NOM_BARRIO                 0
# NOM_CIUDAD                 0
# ESTRATO                   57
# TIPO_INMUEBLE              0
# AREA                       0
# VLR_CANON                  0
# VLR_ADMINISTRACION         0
# FECHA_CONSIGNACION         0
# FECHA_RECONSIGNACION    6408
# FECHA_CONTRATO             1
# COD_ESTADO_CONTRATO        0
# dtype: int64
#    COD_INMUEBLE     NOM_SUCURSAL NOM_BARRIO       NOM_CIUDAD ESTRATO  \
# 0             1  BARRANCABERMEJA  EL PALMAR  BARRANCABERMEJA  CUATRO
# 1             2  BARRANCABERMEJA   COLOMBIA  BARRANCABERMEJA    TRES
# 2             3  BARRANCABERMEJA   COLOMBIA  BARRANCABERMEJA    TRES
# 3             4  BARRANCABERMEJA   COLOMBIA  BARRANCABERMEJA    TRES
# 4             5  BARRANCABERMEJA  TORCOROMA  BARRANCABERMEJA    TRES
#
#   TIPO_INMUEBLE  AREA  VLR_CANON  VLR_ADMINISTRACION FECHA_CONSIGNACION  \
# 0   APARTAMENTO    23     632600              167400         10/09/2020
# 1         LOCAL    11     500000                   0         11/04/2018
# 2   APARTAMENTO    24     500000                   0         11/04/2018
# 3         LOCAL    20     515900                   0         11/04/2018
# 4   APARTAMENTO    33     729000              271000         22/09/2020
#
#   FECHA_RECONSIGNACION FECHA_CONTRATO COD_ESTADO_CONTRATO
# 0                  NaN     12/09/2020             VIGENTE
# 1                  NaN     26/11/2020             VIGENTE
# 2                  NaN     22/06/2019            INACTIVO
# 3                  NaN     18/04/2018            INACTIVO
# 4                  NaN     24/10/2020             VIGENTE

# %%
def replace_nan_values(column):
    for i in range(len(df[column])):
        if df.isnull()[column][i]:
            df.loc[i, column] = stat.mode(df[column])


for i in range(len(df['ESTRATO'])):
    if df['ESTRATO'][i] == 'SIN ASIGNAR':
        df.loc[i, 'ESTRATO'] = np.nan

replace_nan_values('ESTRATO')

# %%
print("\nValores nulos totales:\n", df.isnull().sum())
# Out:
# Valores nulos totales:
#  COD_INMUEBLE               0
# NOM_SUCURSAL               0
# NOM_BARRIO                 0
# NOM_CIUDAD                 0
# ESTRATO                    0
# TIPO_INMUEBLE              0
# AREA                       0
# VLR_CANON                  0
# VLR_ADMINISTRACION         0
# FECHA_CONSIGNACION         0
# FECHA_RECONSIGNACION    6408
# FECHA_CONTRATO             1
# COD_ESTADO_CONTRATO        0
# dtype: int64

# %%
label_encoder = preprocessing.LabelEncoder()
df['NOM_SUCURSAL'] = label_encoder.fit_transform(df['NOM_SUCURSAL'])
df['NOM_BARRIO'] = label_encoder.fit_transform(df['NOM_BARRIO'])
df['NOM_CIUDAD'] = label_encoder.fit_transform(df['NOM_CIUDAD'])
df['ESTRATO'] = label_encoder.fit_transform(df['ESTRATO'])
df['TIPO_INMUEBLE'] = label_encoder.fit_transform(df['TIPO_INMUEBLE'])
df['COD_ESTADO_CONTRATO'] = label_encoder.fit_transform(df['COD_ESTADO_CONTRATO'])

# %%
print("\nColumnas del modelo: \n", df.head(10))
# Out:
# Columnas del modelo:
#     COD_INMUEBLE  NOM_SUCURSAL  NOM_BARRIO  NOM_CIUDAD  ESTRATO  TIPO_INMUEBLE  \
# 0             1             0          81           0        2              0
# 1             2             0          62           0        5              2
# 2             3             0          62           0        5              0
# 3             4             0          62           0        5              2
# 4             5             0         237           0        5              0
# 5             6             0          62           0        2              1
# 6             7             0         153           0        2              2
# 7             8             0          94           0        2              1
# 8             9             0         124           0        2              2
# 9            10             0         177           0        2              1
#
#    AREA  VLR_CANON  VLR_ADMINISTRACION FECHA_CONSIGNACION  \
# 0    23     632600              167400         10/09/2020
# 1    11     500000                   0         11/04/2018
# 2    24     500000                   0         11/04/2018
# 3    20     515900                   0         11/04/2018
# 4    33     729000              271000         22/09/2020
# 5    23     520600              129400         21/10/2020
# 6    27     650000                   0         19/06/2020
# 7    97     780000                   0          6/12/2019
# 8    29    1100000              170000          7/07/2020
# 9    52     744000              156000         24/01/2020
#
#   FECHA_RECONSIGNACION FECHA_CONTRATO  COD_ESTADO_CONTRATO
# 0                  NaN     12/09/2020                    2
# 1                  NaN     26/11/2020                    2
# 2                  NaN     22/06/2019                    0
# 3                  NaN     18/04/2018                    0
# 4                  NaN     24/10/2020                    2
# 5                  NaN     30/10/2020                    2
# 6                  NaN     30/07/2020                    0
# 7                  NaN     21/02/2020                    0
# 8                  NaN     29/09/2020                    2
# 9                  NaN     30/01/2020                    2

# %%
sb.set(style="whitegrid", context="notebook")
plot_data = df.columns
sb.pairplot(df[plot_data], height=2)
plt.tight_layout()
plt.show()

# %%
correlation_mat = df.corr()
sb.heatmap(correlation_mat, annot=False)
plt.show()

# %%
df.drop(['FECHA_CONTRATO', 'FECHA_RECONSIGNACION', 'FECHA_CONSIGNACION'], axis=1,
        inplace=True)
df.dropna(inplace=True)
print("\nColumnas del modelo: \n", df.head(10))
# Out:
# Columnas del modelo:
#     COD_INMUEBLE  NOM_SUCURSAL  NOM_BARRIO  NOM_CIUDAD  ESTRATO  TIPO_INMUEBLE  \
# 0             1             0          81           0        2              0
# 1             2             0          62           0        5              2
# 2             3             0          62           0        5              0
# 3             4             0          62           0        5              2
# 4             5             0         237           0        5              0
# 5             6             0          62           0        2              1
# 6             7             0         153           0        2              2
# 7             8             0          94           0        2              1
# 8             9             0         124           0        2              2
# 9            10             0         177           0        2              1
#
#    AREA  VLR_CANON  VLR_ADMINISTRACION  COD_ESTADO_CONTRATO
# 0    23     632600              167400                    2
# 1    11     500000                   0                    2
# 2    24     500000                   0                    0
# 3    20     515900                   0                    0
# 4    33     729000              271000                    2
# 5    23     520600              129400                    2
# 6    27     650000                   0                    0
# 7    97     780000                   0                    0
# 8    29    1100000              170000                    2
# 9    52     744000              156000                    2

# %%
x_axis = df.drop("COD_ESTADO_CONTRATO", axis=1)
y_axis = df["COD_ESTADO_CONTRATO"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_axis, y_axis, test_size=0.2, random_state=20)

# %% [markdown]
# ## Entrenando modelo

# %%
from sklearn.tree import DecisionTreeRegressor

regression_tree = DecisionTreeRegressor()
regression_tree.fit(x_train, y_train)

# %% [markdown]
# ## Predicciones

# %%
y_pred = regression_tree.predict(x_test)
inferencia = accuracy_score(y_test, y_pred)
print(f"\nInferencia del modelo: {str(inferencia)} %")
# Out:
# Inferencia del modelo: 0.6225165562913907 %
